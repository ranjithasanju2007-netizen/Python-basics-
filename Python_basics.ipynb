# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjithasanju2007-netizen/Python-basics-/blob/main/Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello world")
# Out:
# Hello world

# %%
print ("Ranjitha")
# Out:
# Ranjitha

# %%
name = "ranju"
year = "2026"

print ("Hello", name)
print (year)
# Out:
# Hello ranju
# 2026

# %%
name = "Ranjitha"
year = "2007"

print(name+year)
# Out:
# Ranjitha2007

# %%
a="10"
b="20"

print (a+b)
# Out:
# 1020

# %%
A=25
B=10

print ("mul",A*B)
print ("div",A/B)
# Out:
# mul 250
# div 2.5

# %%
A=int(input("enter your first number"))
B=int(input ("enter your second number"))

print (A)
print (B)
print (A+B)
# Out:
# enter your first number24
# enter your second number35
# 24
# 35
# 59

# %%
Age=int(input("enter your Age:"))

if Age>=18:
   print("You can vote")

else:
     print("come again next year")
# Out:
# enter your Age:18
# You can vote
