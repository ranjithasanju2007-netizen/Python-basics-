# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjithasanju2007-netizen/Python-basics-/blob/main/Python_basics2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks=int(input("enter your marks:"))
if marks>=50:
   print("you can pass")
else:
     Print ("you can not pass")
# Out:
# enter your marks:70
# you can pass

# %%
def greet():
    print("Hello World")

greet()
# Out:
# Hello World

# %%
def greet (name):
    print("Hello",name)

greet("CSE")
greet ("CSD")
greet ("Civil")
greet ("Mechanical")
# Out:
# Hello CSE
# Hello CSD
# Hello Civil
# Hello Mechanical
